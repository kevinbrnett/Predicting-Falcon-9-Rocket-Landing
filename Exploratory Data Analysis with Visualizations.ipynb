# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load data
df = pd.read_csv('Data/falcon9_df_processed_2.csv')
df.head()
# Out:
#    Unnamed: 0  FlightNumber        Date BoosterVersion  PayloadMass Orbit  \
# 0           0             1  2010-06-04       Falcon 9  6123.547647   LEO
# 1           1             2  2012-05-22       Falcon 9   525.000000   LEO
# 2           2             3  2013-03-01       Falcon 9   677.000000   ISS
# 3           3             4  2013-09-29       Falcon 9   500.000000    PO
# 4           4             5  2013-12-03       Falcon 9  3170.000000   GTO
#
#      LaunchSite      Outcome  Flights  GridFins  Reused   Legs LandingPad  \
# 0  CCSFS SLC 40    None None        1     False   False  False        NaN
# 1  CCSFS SLC 40    None None        1     False   False  False        NaN
# 2  CCSFS SLC 40    None None        1     False   False  False        NaN
# 3   VAFB SLC 4E  False Ocean        1     False   False  False        NaN
# 4  CCSFS SLC 40    None None        1     False   False  False        NaN
#
#    Block  ReusedCount Serial   Longitude   Latitude  Class
# ...

# %%
# Drop 'Unnamed: 0' column
df = df.drop(columns='Unnamed: 0')
df.head()
# Out:
#    FlightNumber        Date BoosterVersion  PayloadMass Orbit    LaunchSite  \
# 0             1  2010-06-04       Falcon 9  6123.547647   LEO  CCSFS SLC 40
# 1             2  2012-05-22       Falcon 9   525.000000   LEO  CCSFS SLC 40
# 2             3  2013-03-01       Falcon 9   677.000000   ISS  CCSFS SLC 40
# 3             4  2013-09-29       Falcon 9   500.000000    PO   VAFB SLC 4E
# 4             5  2013-12-03       Falcon 9  3170.000000   GTO  CCSFS SLC 40
#
#        Outcome  Flights  GridFins  Reused   Legs LandingPad  Block  \
# 0    None None        1     False   False  False        NaN    1.0
# 1    None None        1     False   False  False        NaN    1.0
# 2    None None        1     False   False  False        NaN    1.0
# 3  False Ocean        1     False   False  False        NaN    1.0
# 4    None None        1     False   False  False        NaN    1.0
#
#    ReusedCount Serial   Longitude   Latitude  Class
# 0            0  B0003  -80.577366  28.561857      1
# ...

# %%
# Change 'Class' to Badoutcome for easier interpretation
df = df.rename(columns={'Class':'Badoutcome'})
df.head()
# Out:
#    FlightNumber        Date BoosterVersion  PayloadMass Orbit    LaunchSite  \
# 0             1  2010-06-04       Falcon 9  6123.547647   LEO  CCSFS SLC 40
# 1             2  2012-05-22       Falcon 9   525.000000   LEO  CCSFS SLC 40
# 2             3  2013-03-01       Falcon 9   677.000000   ISS  CCSFS SLC 40
# 3             4  2013-09-29       Falcon 9   500.000000    PO   VAFB SLC 4E
# 4             5  2013-12-03       Falcon 9  3170.000000   GTO  CCSFS SLC 40
#
#        Outcome  Flights  GridFins  Reused   Legs LandingPad  Block  \
# 0    None None        1     False   False  False        NaN    1.0
# 1    None None        1     False   False  False        NaN    1.0
# 2    None None        1     False   False  False        NaN    1.0
# 3  False Ocean        1     False   False  False        NaN    1.0
# 4    None None        1     False   False  False        NaN    1.0
#
#    ReusedCount Serial   Longitude   Latitude  Badoutcome
# ...

# %%
# Visualize affect of flight number and payload on launch outcome
sns.catplot(y="PayloadMass", x="FlightNumber", hue='Badoutcome', data=df, aspect=3)
plt.xlabel("Flight Number",fontsize=20)
plt.ylabel("Pay load Mass (kg)",fontsize=20)
plt.show()

# %%
# Visualize relationship between flight number and launch site
sns.scatterplot(y="LaunchSite", x="FlightNumber",hue='Badoutcome', data=df)
plt.xlabel("Flight Number",fontsize=20)
plt.ylabel("Launch Site",fontsize=20)
plt.show()

# %%
# Visualize affect of flight number and launch site on launch outcome
sns.catplot(y="LaunchSite", x="FlightNumber", hue="Class", data=df)
plt.xlabel("Flight Number",fontsize=20)
plt.ylabel("Launch Site",fontsize=20)
plt.show()

# %%
# Visualize affect of flight number and launch site on launch outcome
sns.scatterplot(y="PayloadMass", x="LaunchSite", hue="Badoutcome", data=df)
plt.xlabel("Launch Site",fontsize=20)
plt.ylabel("Payload Mass",fontsize=20)
plt.show()

# %%
# Visualize relationship between success rate of each orbit type
success_rate = df.groupby('Orbit')['Badoutcome'].mean()
success_rate
# Out:
# Orbit
# ES-L1    0.000000
# GEO      0.000000
# GTO      0.481481
# HEO      0.000000
# ISS      0.380952
# LEO      0.285714
# MEO      0.333333
# PO       0.333333
# SO       1.000000
# SSO      0.000000
# VLEO     0.142857
# Name: Badoutcome, dtype: float64

# %%
sns.barplot(data=df,x='Orbit',y='Badoutcome');

# %%
# Relationship between payload and orbit
sns.scatterplot(y="Orbit", x="PayloadMass", hue="Badoutcome", data=df)
plt.xlabel("Payload Mass",fontsize=20)
plt.ylabel("Orbit",fontsize=20)
plt.show()

# %%
# A function to Extract years from the date 
year=[]
def Extract_year():
    for i in df["Date"]:
        year.append(i.split("-")[0])
    return year
Extract_year()
df['Date'] = year
df.head()
# Out:
#    FlightNumber  Date BoosterVersion  PayloadMass Orbit    LaunchSite  \
# 0             1  2010       Falcon 9  6123.547647   LEO  CCSFS SLC 40
# 1             2  2012       Falcon 9   525.000000   LEO  CCSFS SLC 40
# 2             3  2013       Falcon 9   677.000000   ISS  CCSFS SLC 40
# 3             4  2013       Falcon 9   500.000000    PO   VAFB SLC 4E
# 4             5  2013       Falcon 9  3170.000000   GTO  CCSFS SLC 40
#
#        Outcome  Flights  GridFins  Reused   Legs LandingPad  Block  \
# 0    None None        1     False   False  False        NaN    1.0
# 1    None None        1     False   False  False        NaN    1.0
# 2    None None        1     False   False  False        NaN    1.0
# 3  False Ocean        1     False   False  False        NaN    1.0
# 4    None None        1     False   False  False        NaN    1.0
#
#    ReusedCount Serial   Longitude   Latitude  Badoutcome
# 0            0  B0003  -80.577366  28.561857           1
# ...

# %%
# Line chart showing the success trend of the years
sns.lineplot(data=df,x='Date',y='Badoutcome');

# %%
# Save features that will be used later for machine learning
features = df[['FlightNumber', 'PayloadMass', 'Orbit', 'LaunchSite', 'Flights', 'GridFins', 'Reused', 'Legs', 'LandingPad', 'Block', 'ReusedCount', 'Serial']]
features.head()
# Out:
#    FlightNumber  PayloadMass Orbit    LaunchSite  Flights  GridFins  Reused  \
# 0             1  6123.547647   LEO  CCSFS SLC 40        1     False   False
# 1             2   525.000000   LEO  CCSFS SLC 40        1     False   False
# 2             3   677.000000   ISS  CCSFS SLC 40        1     False   False
# 3             4   500.000000    PO   VAFB SLC 4E        1     False   False
# 4             5  3170.000000   GTO  CCSFS SLC 40        1     False   False
#
#     Legs LandingPad  Block  ReusedCount Serial
# 0  False        NaN    1.0            0  B0003
# 1  False        NaN    1.0            0  B0005
# 2  False        NaN    1.0            0  B0007
# 3  False        NaN    1.0            0  B1003
# 4  False        NaN    1.0            0  B1004

# %%
features.to_csv('Data/features_df.csv')
